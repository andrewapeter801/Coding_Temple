# %%
import pandas as pd
import plotly.express as px
import sqlalchemy

# %%
df=pd.read_csv(r'C:\Users\bioni\OneDrive\Documents\GitHub\Coding_Temple\Wk 6\Lecture Notes\Day 2\accessories.csv')

df
# Out:
#                      Name   Variation DIY   Buy  Sell Color 1   Color 2 Size  \
# 0              3D glasses       White  No   490   122   White  Colorful  1x1
# 1              3D glasses       Black  No   490   122   Black  Colorful  1x1
# 2                 bandage       Beige  No   140    35   Beige     White  1x1
# 3                    beak      Yellow  No   490   122  Yellow    Yellow  1x1
# 4         birthday shades      Yellow  No   NFS   620  Yellow       Red  1x1
# ..                    ...         ...  ..   ...   ...     ...       ...  ...
# 217       triangle shades       Green  No   880   220   Green    Purple  1x1
# 218       triangle shades       White  No   880   220   White    Purple  1x1
# 219       triangle shades       Black  No   880   220   Black    Purple  1x1
# 220  wooden-frame glasses       Brown  No  1560   390   Brown      Gray  1x1
# 221  wooden-frame glasses  Dark brown  No  1560   390   Brown    Yellow  1x1
#
# ...

# %% [markdown]
# ## Step 2: Tidy Data
# - Tidy column names
# - Check for null values
# - Check our data types
# - Convert Yes/No to boolean

# %%
# Normalize column names
df.columns = df.columns.str.strip().str.replace(' ','_')

# %%
df.columns
# Out:
# Index(['Name', 'Variation', 'DIY', 'Buy', 'Sell', 'Color_1', 'Color_2', 'Size',
#        'Miles_Price', 'Source', 'Source_Notes', 'Seasonal_Availability',
#        'Mannequin_Piece', 'Version', 'Style', 'Label_Themes', 'Type',
#        'Villager_Equippable', 'Catalog', 'Filename', 'Internal_ID',
#        'Unique_Entry_ID'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222 entries, 0 to 221
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name                   222 non-null    object
#  1   Variation              222 non-null    object
#  2   DIY                    222 non-null    object
#  3   Buy                    222 non-null    object
#  4   Sell                   222 non-null    int64
#  5   Color_1                222 non-null    object
#  6   Color_2                222 non-null    object
#  7   Size                   222 non-null    object
#  8   Miles_Price            1 non-null      float64
#  9   Source                 222 non-null    object
#  10  Source_Notes           206 non-null    object
#  11  Seasonal_Availability  222 non-null    object
#  12  Mannequin_Piece        222 non-null    object
#  13  Version                222 non-null    object
# ...

# %%
# Let's take a look at the BUY column
df['Buy'].value_counts()
df['Buy'].replace('NFS', -1, inplace= True)

# Cast as an INT
df['Buy'] = df['Buy'].astype('int')

# %%
df.drop(columns='Miles_Price', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222 entries, 0 to 221
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name                   222 non-null    object
#  1   Variation              222 non-null    object
#  2   DIY                    222 non-null    object
#  3   Buy                    222 non-null    int32
#  4   Sell                   222 non-null    int64
#  5   Color_1                222 non-null    object
#  6   Color_2                222 non-null    object
#  7   Size                   222 non-null    object
#  8   Source                 222 non-null    object
#  9   Source_Notes           206 non-null    object
#  10  Seasonal_Availability  222 non-null    object
#  11  Mannequin_Piece        222 non-null    object
#  12  Version                222 non-null    object
#  13  Style                  222 non-null    object
# ...

# %%
df[df['Source_Notes']].isna() == True
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\bioni\OneDrive\Documents\GitHub\Coding_Temple\Wk 6\Lecture Notes\Day 2\part_2_animal_crossing.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/bioni/OneDrive/Documents/GitHub/Coding_Temple/Wk%206/Lecture%20Notes/Day%202/part_2_animal_crossing.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> df[df['Source_Notes']].isna() == True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:3902, in DataFrame.__getitem__(self, key)
#    3900     if is_iterator(key):
#    3901         key = list(key)
# -> 3902     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3904 # take() does not accept boolean indexers
#    3905 if getattr(indexer, "dtype", None) == bool:
#
# ...

# %%
df['Source_Notes'].fillna('Available through Event Participation', inplace= True)

# %%
df['Label_Themes'] = df['Label_Themes'].str.split(';')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222 entries, 0 to 221
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name                   222 non-null    object
#  1   Variation              222 non-null    object
#  2   DIY                    222 non-null    object
#  3   Buy                    222 non-null    int32
#  4   Sell                   222 non-null    int64
#  5   Color_1                222 non-null    object
#  6   Color_2                222 non-null    object
#  7   Size                   222 non-null    object
#  8   Source                 222 non-null    object
#  9   Source_Notes           222 non-null    object
#  10  Seasonal_Availability  222 non-null    object
#  11  Mannequin_Piece        222 non-null    object
#  12  Version                222 non-null    object
#  13  Style                  222 non-null    object
# ...

# %%
df
# Out:
#                      Name   Variation DIY   Buy  Sell Color_1   Color_2 Size  \
# 0              3D glasses       White  No   490   122   White  Colorful  1x1
# 1              3D glasses       Black  No   490   122   Black  Colorful  1x1
# 2                 bandage       Beige  No   140    35   Beige     White  1x1
# 3                    beak      Yellow  No   490   122  Yellow    Yellow  1x1
# 4         birthday shades      Yellow  No    -1   620  Yellow       Red  1x1
# ..                    ...         ...  ..   ...   ...     ...       ...  ...
# 217       triangle shades       Green  No   880   220   Green    Purple  1x1
# 218       triangle shades       White  No   880   220   White    Purple  1x1
# 219       triangle shades       Black  No   880   220   Black    Purple  1x1
# 220  wooden-frame glasses       Brown  No  1560   390   Brown      Gray  1x1
# 221  wooden-frame glasses  Dark brown  No  1560   390   Brown    Yellow  1x1
#
# ...

# %%
# How do I calculate 30%?
threshold = int(len(df)* .3)
threshold
# Out:
# 66

# %%
col_to_drop = []
for col in df.columns:
    if df[col].nunique() >= threshold:
        col_to_drop.append(col)
col_to_drop
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\bioni\OneDrive\Documents\GitHub\Coding_Temple\Wk 6\Lecture Notes\Day 2\part_2_animal_crossing.ipynb Cell 17 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/bioni/OneDrive/Documents/GitHub/Coding_Temple/Wk%206/Lecture%20Notes/Day%202/part_2_animal_crossing.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> col_to_drop = []
#       <a href='vscode-notebook-cell:/c%3A/Users/bioni/OneDrive/Documents/GitHub/Coding_Temple/Wk%206/Lecture%20Notes/Day%202/part_2_animal_crossing.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> for col in df.columns:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/bioni/OneDrive/Documents/GitHub/Coding_Temple/Wk%206/Lecture%20Notes/Day%202/part_2_animal_crossing.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a>     if df[col].nunique() >= threshold:
# ...

# %%
df.to_sql('animal_crossing_accessories', con= my_con, if_exists='replace', index=False)

# %%
df.to_csv('animal_crossing_accessories.csv', index=False)
