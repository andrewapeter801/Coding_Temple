# %% [markdown]
# # Data Visualization Assignment (Matplotlib & Seaborn)
# Author: Katie Sylvia

# %% [markdown]
# Data set in the data folder as `auto_mpg_dataset.csv`. Dataset is of cars from the 1970s and 1980s.<br>
# Data from: https://www.mldata.io/datasets-sort/regression/<br>

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read in the data
auto = pd.read_csv(r'C:\Users\bioni\OneDrive\Documents\GitHub\Coding_Temple\Week 4\Assignments\D2\hw-data-viz-main\data\auto_mpg_dataset.csv')

auto
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0            8         307.0       130.0  3504.0          12.0          70
# 1            8         350.0       165.0  3693.0          11.5          70
# 2            8         318.0       150.0  3436.0          11.0          70
# 3            8         304.0       150.0  3433.0          12.0          70
# 4            8         302.0       140.0  3449.0          10.5          70
# ..         ...           ...         ...     ...           ...         ...
# 393          4         140.0        86.0  2790.0          15.6          82
# 394          4          97.0        52.0  2130.0          24.6          82
# 395          4         135.0        84.0  2295.0          11.6          82
# 396          4         120.0        79.0  2625.0          18.6          82
# 397          4         119.0        82.0  2720.0          19.4          82
#
#      origin                   car_name   mpg
# ...

# %%
# Display the first 5 rows
auto.head()
# Out:
#    cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0          8         307.0       130.0  3504.0          12.0          70
# 1          8         350.0       165.0  3693.0          11.5          70
# 2          8         318.0       150.0  3436.0          11.0          70
# 3          8         304.0       150.0  3433.0          12.0          70
# 4          8         302.0       140.0  3449.0          10.5          70
#
#    origin                   car_name   mpg
# 0       1  chevrolet chevelle malibu  18.0
# 1       1          buick skylark 320  15.0
# 2       1         plymouth satellite  18.0
# 3       1              amc rebel sst  16.0
# 4       1                ford torino  17.0

# %%
# Summary statistics (using .describe())
auto.describe().round(2)
# Out:
#        cylinders  displacement  horsepower   weight  acceleration  model_year  \
# count     398.00        398.00      398.00   398.00        398.00      398.00
# mean        5.45        193.43    -1404.64  2970.42         15.57       76.01
# std         1.70        104.27    12213.42   846.84          2.76        3.70
# min         3.00         68.00  -100000.00  1613.00          8.00       70.00
# 25%         4.00        104.25       75.00  2223.75         13.82       73.00
# 50%         4.00        148.50       92.00  2803.50         15.50       76.00
# 75%         8.00        262.00      125.00  3608.00         17.18       79.00
# max         8.00        455.00      230.00  5140.00         24.80       82.00
#
#        origin     mpg
# count  398.00  398.00
# mean     1.57   23.51
# std      0.80    7.82
# min      1.00    9.00
# 25%      1.00   17.50
# 50%      1.00   23.00
# 75%      2.00   29.00
# max      3.00   46.60

# %% [markdown]
# ## Data Cleaning

# %%
# Check the datatypes
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cylinders     398 non-null    int64
#  1   displacement  398 non-null    float64
#  2   horsepower    398 non-null    float64
#  3   weight        398 non-null    float64
#  4   acceleration  398 non-null    float64
#  5   model_year    398 non-null    int64
#  6   origin        398 non-null    int64
#  7   car_name      398 non-null    object
#  8   mpg           398 non-null    float64
# dtypes: float64(5), int64(3), object(1)
# memory usage: 28.1+ KB

# %%
# Check for null values
auto.isnull().sum()
# Out:
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# car_name        0
# mpg             0
# dtype: int64

# %%
# Drop the non-numerical column
auto.del(car_name())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\bioni\OneDrive\Documents\GitHub\Coding_Temple\Week 4\Assignments\D2\hw-data-viz-main\data-viz-starter-code.ipynb Cell 10 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/bioni/OneDrive/Documents/GitHub/Coding_Temple/Week%204/Assignments/D2/hw-data-viz-main/data-viz-starter-code.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> # Drop the non-numerical column
# ----> <a href='vscode-notebook-cell:/c%3A/Users/bioni/OneDrive/Documents/GitHub/Coding_Temple/Week%204/Assignments/D2/hw-data-viz-main/data-viz-starter-code.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> auto.drop(car_name())
#
# NameError: name 'car_name' is not defined

# %% [markdown]
# ## Correlations

# %%
# Get correlations for numeric data
auto.corr(numeric_only= True)
# Out:
#               cylinders  displacement  horsepower    weight  acceleration  \
# cylinders      1.000000      0.950721    0.084291  0.896017     -0.505419
# displacement   0.950721      1.000000    0.079333  0.932824     -0.543684
# horsepower     0.084291      0.079333    1.000000  0.071114     -0.080685
# weight         0.896017      0.932824    0.071114  1.000000     -0.417457
# acceleration  -0.505419     -0.543684   -0.080685 -0.417457      1.000000
# model_year    -0.348746     -0.370164   -0.067952 -0.306564      0.288137
# origin        -0.562543     -0.609409    0.035575 -0.581024      0.205873
# mpg           -0.775396     -0.804203   -0.073501 -0.831741      0.420289
#
#               model_year    origin       mpg
# cylinders      -0.348746 -0.562543 -0.775396
# displacement   -0.370164 -0.609409 -0.804203
# horsepower     -0.067952  0.035575 -0.073501
# weight         -0.306564 -0.581024 -0.831741
# acceleration    0.288137  0.205873  0.420289
# ...

# %%
# Create a heatmap
# Establish size of figure.
plt.figure(figsize= (16,9))
# Get correlation of variables.
corr = auto.corr(numeric_only= True)
# Set up mask to be "True" in the upper triangle.
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

# Plot our correlation heatmap
sns.heatmap(corr,
            square= True,
            cmap= 'coolwarm',
            annot= True,
            vmax=1,
            vmin=-1,
            mask=mask);

# %%
# What if we ONLY wanted to look at how the features correlate with `mpg`?
#auto.corr(numeric_only= True)[['mpg']].sort_values(by='mpg', ascending=False)
sns.heatmap(auto.corr(numeric_only= True)[['mpg']].sort_values(by='mpg', ascending=False),
            annot = True,
            vmax=1,
            vmin=-1,
            cmap='coolwarm');

# %% [markdown]
# For more Seaborn color palettes, click [here](https://seaborn.pydata.org/tutorial/color_palettes.html).

# %% [markdown]
# ## Countplots

# %% [markdown]
# **Distribution of Model Year**

# %%
#size
plt.figure(figsize=(12,5))

sns.countplot(x = auto['model_year'])
# Out:
# <Axes: xlabel='model_year', ylabel='count'>

# %% [markdown]
# **Distribution of Origin**

# %%
#size
plt.figure(figsize=(12,5))

sns.countplot(x = auto['origin'])
# Out:
# <Axes: xlabel='origin', ylabel='count'>

# %% [markdown]
# **Distribution of Cylinders**

# %%
#size
plt.figure(figsize=(12,5))

sns.countplot(x = auto['cylinders'])
# Out:
# <Axes: xlabel='cylinders', ylabel='count'>

# %% [markdown]
# ## Boxplots/Histograms

# %% [markdown]
# **MPG Distribution**

# %%
# Plot it
sns.histplot(auto['mpg'], color= 'blue', bins= 20)
# Create a descriptive title
plt.title('MPG Distribution');

# %% [markdown]
# **Weight Distribution**

# %%
# Plot it
sns.histplot(auto['weight'], color= 'yellow', bins= 20)
# Create a descriptive title
plt.title('Weight Distribution');

# %% [markdown]
# ## Scatterplots

# %% [markdown]
# **Weight vs. MPG**

# %%
# Size
plt.figure(figsize= (12,5))


# Plot it
plt.scatter(x = auto['weight'], y = auto['mpg']);
# Create a descriptive title
plt.title('Weight vs MPG')
# Add axis labels
plt.xlabel('Weight of Each Vehicle')
plt.ylabel('Miles per Gallon(MPG)');

# %% [markdown]
# ## Your turn!

# %%
# Create more plot(s) of your choosing to help you explore the data!

# Acceleration vs MPG
# Size
plt.figure(figsize= (12,5))


# Plot it
plt.scatter(x = auto['acceleration'], y = auto['mpg']);
# Create a descriptive title
plt.title('Acceleration vs MPG')
# Add axis labels
plt.xlabel('Acceleration')
plt.ylabel('Miles per Gallon (MPG)');
