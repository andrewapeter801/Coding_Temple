# %% [markdown]
# # Coding Temple's Data Analytics Program
# ---
# ## Intro to API's Assignment
# ---
# ### Problem 1:
# Check out this Pokemon API https://pokeapi.co/
# Use the requests package to connect to this API and get and store data for 5 different pokemon.
# Get the pokemons: name, atleast one ability's name, base_experience, and the URL for its sprite (an image that shows up on screen) for the 'front_shiny', attack base_state, hp base_stat, defense base_stat
#
# **BONUS POINTS IF YOU CAN POPULATE THE IMAGE!**

# %%
import requests, json
from PIL import Image
from io import BytesIO

# %% [markdown]
# Charizard

# %%
chari = 'https://pokeapi.co/api/v2/pokemon/charizard'

response = requests.get(chari)

print(response)

response.ok

response.json()
# Out:
# <Response [200]>
# {'abilities': [{'ability': {'name': 'blaze',
#     'url': 'https://pokeapi.co/api/v2/ability/66/'},
#    'is_hidden': False,
#    'slot': 1},
#   {'ability': {'name': 'solar-power',
#     'url': 'https://pokeapi.co/api/v2/ability/94/'},
#    'is_hidden': True,
#    'slot': 3}],
#  'base_experience': 267,
#  'forms': [{'name': 'charizard',
#    'url': 'https://pokeapi.co/api/v2/pokemon-form/6/'}],
#  'game_indices': [{'game_index': 180,
#    'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}},
#   {'game_index': 180,
#    'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}},
#   {'game_index': 180,
#    'version': {'name': 'yellow',
#     'url': 'https://pokeapi.co/api/v2/version/3/'}},
#   {'game_index': 6,
#    'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}},
#   {'game_index': 6,
#    'version': {'name': 'silver',
#     'url': 'https://pokeapi.co/api/v2/version/5/'}},
#   {'game_index': 6,
# ...

# %%
chari_ex = response.json()['base_experience']
chari_ex
# Out:
# 239

# %%
chari_ability = response.json()['abilities']
chari_ability
# Out:
# [{'ability': {'name': 'torrent',
#    'url': 'https://pokeapi.co/api/v2/ability/67/'},
#   'is_hidden': False,
#   'slot': 1},
#  {'ability': {'name': 'competitive',
#    'url': 'https://pokeapi.co/api/v2/ability/172/'},
#   'is_hidden': True,
#   'slot': 3}]

# %%
chari_hp = response.json()['stats'][0]
chari_hp
# Out:
# {'base_stat': 78,
#  'effort': 0,
#  'stat': {'name': 'hp', 'url': 'https://pokeapi.co/api/v2/stat/1/'}}

# %%
chari_attact = response.json()['stats'][1]
chari_attact
# Out:
# {'base_stat': 84,
#  'effort': 0,
#  'stat': {'name': 'attack', 'url': 'https://pokeapi.co/api/v2/stat/2/'}}

# %%
chari_def = response.json()['stats'][2]
chari_def
# Out:
# {'base_stat': 78,
#  'effort': 0,
#  'stat': {'name': 'defense', 'url': 'https://pokeapi.co/api/v2/stat/3/'}}

# %%
Image.open(BytesIO(requests.get(requests.get('https://pokeapi.co/api/v2/pokemon/charizard').json()['sprites']['front_shiny']).content))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\PIL\JpegImagePlugin.py:639, in _save(im, fp, filename)
#     638 try:
# --> 639     rawmode = RAWMODE[im.mode]
#     640 except KeyError as e:
#
# KeyError: 'P'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\PIL\Image.py:643, in Image._repr_image(self, image_format, **kwargs)
#     642 try:
# --> 643     self.save(b, image_format, **kwargs)
#     644 except Exception as e:
#
# ...

# %% [markdown]
# Empoleon

# %%
emp = 'https://pokeapi.co/api/v2/pokemon/empoleon'

response = requests.get(emp)

print(response)

response.ok

response.json()
# Out:
# <Response [200]>
# {'abilities': [{'ability': {'name': 'torrent',
#     'url': 'https://pokeapi.co/api/v2/ability/67/'},
#    'is_hidden': False,
#    'slot': 1},
#   {'ability': {'name': 'competitive',
#     'url': 'https://pokeapi.co/api/v2/ability/172/'},
#    'is_hidden': True,
#    'slot': 3}],
#  'base_experience': 239,
#  'forms': [{'name': 'empoleon',
#    'url': 'https://pokeapi.co/api/v2/pokemon-form/395/'}],
#  'game_indices': [{'game_index': 395,
#    'version': {'name': 'diamond',
#     'url': 'https://pokeapi.co/api/v2/version/12/'}},
#   {'game_index': 395,
#    'version': {'name': 'pearl',
#     'url': 'https://pokeapi.co/api/v2/version/13/'}},
#   {'game_index': 395,
#    'version': {'name': 'platinum',
#     'url': 'https://pokeapi.co/api/v2/version/14/'}},
#   {'game_index': 395,
#    'version': {'name': 'heartgold',
#     'url': 'https://pokeapi.co/api/v2/version/15/'}},
#   {'game_index': 395,
#    'version': {'name': 'soulsilver',
# ...

# %%
emp_ability = response.json()['abilities'][1]['ability']['name']
emp_ability
# Out:
# 'competitive'

# %%
emp_ex = response.json()['base_experience']
emp_ex
# Out:
# 239

# %%
emp_attact = response.json()['stats'][1]
emp_attact
# Out:
# {'base_stat': 86,
#  'effort': 0,
#  'stat': {'name': 'attack', 'url': 'https://pokeapi.co/api/v2/stat/2/'}}

# %%
emp_hp = response.json()['stats'][0]
emp_hp
# Out:
# {'base_stat': 84,
#  'effort': 0,
#  'stat': {'name': 'hp', 'url': 'https://pokeapi.co/api/v2/stat/1/'}}

# %%
emp_defense = response.json()['stats'][2]
emp_defense
# Out:
# {'base_stat': 88,
#  'effort': 0,
#  'stat': {'name': 'defense', 'url': 'https://pokeapi.co/api/v2/stat/3/'}}

# %%
Image.open(BytesIO(requests.get(requests.get('https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/395.png').json()).content))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# c:\Users\bioni\OneDrive\Documents\GitHub\Coding_Temple\Week 4\Assignments\intro_to_apis.ipynb Cell 18 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/bioni/OneDrive/Documents/GitHub/Coding_Temple/Week%204/Assignments/intro_to_apis.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> Image.open(BytesIO(requests.get(requests.get('https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/395.png').json()).content))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\requests\models.py:897, in Response.json(self, **kwargs)
#     891         except UnicodeDecodeError:
#     892             # Wrong UTF codec detected; usually because it's not UTF-8
#     893             # but some other 8-bit codec.  This is an RFC violation,
# ...

# %% [markdown]
# Squirtle

# %%
squir = 'https://pokeapi.co/api/v2/pokemon/squirtle'

response = requests.get(squir)

print(response)

response.ok

response.json()
# Out:
# <Response [200]>
# {'abilities': [{'ability': {'name': 'torrent',
#     'url': 'https://pokeapi.co/api/v2/ability/67/'},
#    'is_hidden': False,
#    'slot': 1},
#   {'ability': {'name': 'rain-dish',
#     'url': 'https://pokeapi.co/api/v2/ability/44/'},
#    'is_hidden': True,
#    'slot': 3}],
#  'base_experience': 63,
#  'forms': [{'name': 'squirtle',
#    'url': 'https://pokeapi.co/api/v2/pokemon-form/7/'}],
#  'game_indices': [{'game_index': 177,
#    'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}},
#   {'game_index': 177,
#    'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}},
#   {'game_index': 177,
#    'version': {'name': 'yellow',
#     'url': 'https://pokeapi.co/api/v2/version/3/'}},
#   {'game_index': 7,
#    'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}},
#   {'game_index': 7,
#    'version': {'name': 'silver',
#     'url': 'https://pokeapi.co/api/v2/version/5/'}},
#   {'game_index': 7,
# ...

# %%
squir_ability = response.json()['abilities'][1]['ability']['name']
squir_ability
# Out:
# 'rain-dish'

# %%
squir_ex = response.json()['base_experience']
squir_ex
# Out:
# 63

# %%
squir_attack = response.json()['stats'][1]
squir_attack
# Out:
# {'base_stat': 48,
#  'effort': 0,
#  'stat': {'name': 'attack', 'url': 'https://pokeapi.co/api/v2/stat/2/'}}

# %%
squir_hp = response.json()['stats'][0]
squir_hp
# Out:
# {'base_stat': 44,
#  'effort': 0,
#  'stat': {'name': 'hp', 'url': 'https://pokeapi.co/api/v2/stat/1/'}}

# %%
squir_d = response.json()['stats'][2]
squir_d
# Out:
# {'base_stat': 65,
#  'effort': 1,
#  'stat': {'name': 'defense', 'url': 'https://pokeapi.co/api/v2/stat/3/'}}

# %%
Image.open(BytesIO(requests.get(requests.get('https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/7.png').json()).content))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# c:\Users\bioni\OneDrive\Documents\GitHub\Coding_Temple\Week 4\Assignments\intro_to_apis.ipynb Cell 26 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/bioni/OneDrive/Documents/GitHub/Coding_Temple/Week%204/Assignments/intro_to_apis.ipynb#X44sZmlsZQ%3D%3D?line=0'>1</a> Image.open(BytesIO(requests.get(requests.get('https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/7.png').json()).content))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\requests\models.py:897, in Response.json(self, **kwargs)
#     891         except UnicodeDecodeError:
#     892             # Wrong UTF codec detected; usually because it's not UTF-8
#     893             # but some other 8-bit codec.  This is an RFC violation,
# ...

# %% [markdown]
# Beedrill

# %%
beed = 'https://pokeapi.co/api/v2/pokemon/beedrill'

response = requests.get( beed)

print(response)

response.ok

response.json()
# Out:
# <Response [200]>
# {'abilities': [{'ability': {'name': 'swarm',
#     'url': 'https://pokeapi.co/api/v2/ability/68/'},
#    'is_hidden': False,
#    'slot': 1},
#   {'ability': {'name': 'sniper',
#     'url': 'https://pokeapi.co/api/v2/ability/97/'},
#    'is_hidden': True,
#    'slot': 3}],
#  'base_experience': 178,
#  'forms': [{'name': 'beedrill',
#    'url': 'https://pokeapi.co/api/v2/pokemon-form/15/'}],
#  'game_indices': [{'game_index': 114,
#    'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}},
#   {'game_index': 114,
#    'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}},
#   {'game_index': 114,
#    'version': {'name': 'yellow',
#     'url': 'https://pokeapi.co/api/v2/version/3/'}},
#   {'game_index': 15,
#    'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}},
#   {'game_index': 15,
#    'version': {'name': 'silver',
#     'url': 'https://pokeapi.co/api/v2/version/5/'}},
#   {'game_index': 15,
# ...

# %%
beed_ability = response.json()['abilities'][1]['ability']['name']
beed_ability
# Out:
# 'rain-dish'

# %%
beed_ex = response.json()['base_experience']
beed_ex
# Out:
# 63

# %%
beed_attack = response.json()['stats'][1]
beed_attack
# Out:
# {'base_stat': 48,
#  'effort': 0,
#  'stat': {'name': 'attack', 'url': 'https://pokeapi.co/api/v2/stat/2/'}}

# %%
beed_hp = response.json()['stats'][0]
beed_hp
# Out:
# {'base_stat': 44,
#  'effort': 0,
#  'stat': {'name': 'hp', 'url': 'https://pokeapi.co/api/v2/stat/1/'}}

# %%
beed_d = response.json()['stats'][2]
beed_d
# Out:
# {'base_stat': 65,
#  'effort': 1,
#  'stat': {'name': 'defense', 'url': 'https://pokeapi.co/api/v2/stat/3/'}}

# %%
Image.open(BytesIO(requests.get(requests.get('https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/15.pn').json()).content))

'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/15.pn'
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# c:\Users\bioni\OneDrive\Documents\GitHub\Coding_Temple\Week 4\Assignments\intro_to_apis.ipynb Cell 34 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/bioni/OneDrive/Documents/GitHub/Coding_Temple/Week%204/Assignments/intro_to_apis.ipynb#X62sZmlsZQ%3D%3D?line=0'>1</a> Image.open(BytesIO(requests.get(requests.get('https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/15.pn').json()).content))
#       <a href='vscode-notebook-cell:/c%3A/Users/bioni/OneDrive/Documents/GitHub/Coding_Temple/Week%204/Assignments/intro_to_apis.ipynb#X62sZmlsZQ%3D%3D?line=2'>3</a> 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/15.pn'
#
# ...

# %% [markdown]
# Bulbasaur

# %%
bulb = 'https://pokeapi.co/api/v2/pokemon/bulbasaur'

response = requests.get(bulb)

print(response)

response.ok

response.json()
# Out:
# <Response [200]>
# {'abilities': [{'ability': {'name': 'overgrow',
#     'url': 'https://pokeapi.co/api/v2/ability/65/'},
#    'is_hidden': False,
#    'slot': 1},
#   {'ability': {'name': 'chlorophyll',
#     'url': 'https://pokeapi.co/api/v2/ability/34/'},
#    'is_hidden': True,
#    'slot': 3}],
#  'base_experience': 64,
#  'forms': [{'name': 'bulbasaur',
#    'url': 'https://pokeapi.co/api/v2/pokemon-form/1/'}],
#  'game_indices': [{'game_index': 153,
#    'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}},
#   {'game_index': 153,
#    'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}},
#   {'game_index': 153,
#    'version': {'name': 'yellow',
#     'url': 'https://pokeapi.co/api/v2/version/3/'}},
#   {'game_index': 1,
#    'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}},
#   {'game_index': 1,
#    'version': {'name': 'silver',
#     'url': 'https://pokeapi.co/api/v2/version/5/'}},
# ...

# %%
bulb_ability = response.json()['abilities'][1]['ability']['name']
bulb_ability
# Out:
# 'chlorophyll'

# %%
bulb_ex = response.json()['base_experience']
beed_ex
# Out:
# 63

# %%
bulb_attack = response.json()['stats'][1]
bulb_attack
# Out:
# {'base_stat': 49,
#  'effort': 0,
#  'stat': {'name': 'attack', 'url': 'https://pokeapi.co/api/v2/stat/2/'}}

# %%
bulb_hp = response.json()['stats'][0]
bulb_hp
# Out:
# {'base_stat': 45,
#  'effort': 0,
#  'stat': {'name': 'hp', 'url': 'https://pokeapi.co/api/v2/stat/1/'}}

# %%
bulb_d = response.json()['stats'][2]
bulb_d
# Out:
# {'base_stat': 49,
#  'effort': 0,
#  'stat': {'name': 'defense', 'url': 'https://pokeapi.co/api/v2/stat/3/'}}

# %%
"https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/1.png"

# %% [markdown]
# Charmander

# %%
charm = 'https://pokeapi.co/api/v2/pokemon/charmander'

response = requests.get(charm)

print(response)

response.ok

response.json()
# Out:
# <Response [200]>
# {'abilities': [{'ability': {'name': 'blaze',
#     'url': 'https://pokeapi.co/api/v2/ability/66/'},
#    'is_hidden': False,
#    'slot': 1},
#   {'ability': {'name': 'solar-power',
#     'url': 'https://pokeapi.co/api/v2/ability/94/'},
#    'is_hidden': True,
#    'slot': 3}],
#  'base_experience': 62,
#  'forms': [{'name': 'charmander',
#    'url': 'https://pokeapi.co/api/v2/pokemon-form/4/'}],
#  'game_indices': [{'game_index': 176,
#    'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}},
#   {'game_index': 176,
#    'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}},
#   {'game_index': 176,
#    'version': {'name': 'yellow',
#     'url': 'https://pokeapi.co/api/v2/version/3/'}},
#   {'game_index': 4,
#    'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}},
#   {'game_index': 4,
#    'version': {'name': 'silver',
#     'url': 'https://pokeapi.co/api/v2/version/5/'}},
#   {'game_index': 4,
# ...

# %%
charm_ability = response.json()['abilities'][1]['ability']['name']
charm_ability
# Out:
# 'solar-power'

# %%
charm_base = response.json()['base_experience']
charm_base
# Out:
# 62

# %%
charm_attack = response.json()['stats'][1]
charm_attack
# Out:
# {'base_stat': 52,
#  'effort': 0,
#  'stat': {'name': 'attack', 'url': 'https://pokeapi.co/api/v2/stat/2/'}}

# %%
charm_hp = response.json()['stats'][0]
charm_hp
# Out:
# {'base_stat': 39,
#  'effort': 0,
#  'stat': {'name': 'hp', 'url': 'https://pokeapi.co/api/v2/stat/1/'}}

# %%
charm_d = response.json()['stats'][2]
charm_d
# Out:
# {'base_stat': 43,
#  'effort': 0,
#  'stat': {'name': 'defense', 'url': 'https://pokeapi.co/api/v2/stat/3/'}}

# %%
"https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/4.png"

# %% [markdown]
# ### Problem 2:
#
# I want to build the best Pokemon team I can and I need your help to do so! Using the API, build me a team of 6 pokemon who's base-stats are above 60. Return any additional information you think is needed to help understand why you chose that pokemon for the team!

# %%
print(bulb_ex)
print(chari_ex)
print(emp_ex)
print(charm_base)
print(beed_ex)
print(squir_ex)

# I know nothing about Pokemon to suggest a good reason why they would be good for the team!
# Out:
# 64
# 239
# 239
# 62
# 63
# 63

# %% [markdown]
# ### Problem 3:
#
# Create a function that does the following:
# * Input: pokemon_name(user_defined) -> str
# * Output: list object containing a dictionary of values from the response object.
# * Please include the type, the most current raritey level, at least one held item, and all stats

# %%
pokemon = []
for x in range(1,30):
    url = f"https://pokeapi.co/api/v2/pokemon/{x}/"
    pokemon.append(requests.get(url).json())

# %%
def my_poki(pokemon_name:str):
    data = requests.get(f'https://pokeapi.co/api/v2/pokemon/{pokemon_name.lower()}').json()
    d= {}
    d[poke_names] = {
    'name': data['name'],
    'ability': data['abilities'][0]['ability']['name'],
    }

poke_names = ['charizard','empolean','charmander', 'beedle', 'squirtle','bulbasaur']
poke_data = {}
for name in poke_names:
    poke_data[name] = my_poki(name)
poke_data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\bioni\OneDrive\Documents\GitHub\Coding_Temple\Week 4\Assignments\intro_to_apis.ipynb Cell 64 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/bioni/OneDrive/Documents/GitHub/Coding_Temple/Week%204/Assignments/intro_to_apis.ipynb#Y121sZmlsZQ%3D%3D?line=9'>10</a> poke_data = {}
#      <a href='vscode-notebook-cell:/c%3A/Users/bioni/OneDrive/Documents/GitHub/Coding_Temple/Week%204/Assignments/intro_to_apis.ipynb#Y121sZmlsZQ%3D%3D?line=10'>11</a> for name in poke_names:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/bioni/OneDrive/Documents/GitHub/Coding_Temple/Week%204/Assignments/intro_to_apis.ipynb#Y121sZmlsZQ%3D%3D?line=11'>12</a>     poke_data[name] = my_poki(name)
# ...
